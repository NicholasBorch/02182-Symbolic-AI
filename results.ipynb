# %% [markdown]
# ## Mavis2 Experiment Results
#
# Loads the mavis2 result JSONs via `analysis.load_results`.

# %%
import pandas as pd
from analysis import load_results, load_goal_recognition_results

# %% [markdown]
# ### Exercise 1 (mavis2)

# %%
df_ex1_mavis2 = load_results("data/exercise1_results_mavis2.json").drop(columns=["Heuristic", "Depth"])
df_ex1_mavis2
# Out:
#                Level       Strategy Level solved  States Generated   Time/s  \
# 0   ex1_dec_bad1.lvl  DECENTRALISED           No               189  176.012
# 1   ex1_dec_bad1.lvl            BFS          Yes             65311   12.745
# 2   ex1_dec_bad2.lvl  DECENTRALISED           No               625  177.996
# 3   ex1_dec_bad2.lvl            BFS          Yes            535063  131.833
# 4  ex1_dec_good1.lvl  DECENTRALISED          Yes               497    0.083
# 5  ex1_dec_good1.lvl            BFS          Yes            312288   56.824
# 6  ex1_dec_good2.lvl  DECENTRALISED          Yes               123    0.028
# 7  ex1_dec_good2.lvl            BFS          Yes             45657    8.442
#
#      Steps
# 0  3483447
# 1       11
# 2  3495486
# 3       11
# 4        8
# 5        7
# 6       11
# 7       11

# %% [markdown]
# ### Exercise 2 (mavis2)

# %%
df_ex2_mavis2 = load_results("data/exercise2_results_mavis2.json").drop(columns=["Heuristic", "Depth"])
df_ex2_mavis2
# Out:
#                  Level Strategy Level solved  States Generated  Time/s  Steps
# 0         MAhelper.lvl   HELPER          Yes                36   0.025     29
# 1        MAhelper3.lvl   HELPER          Yes                25   0.011     17
# 2   MAhelperCustom.lvl   HELPER           No                57   0.010      4
# 3  MAhelperCustom2.lvl   HELPER           No                57   0.019     13
# 4  MAhelperCustom3.lvl   HELPER          Yes                36   0.016     15
# 5  MAhelperCustom4.lvl   HELPER           No                36   0.017     15
# 6        MAExample.lvl   HELPER           No                31   0.024     19

# %% [markdown]
# ### Exercise 3 (mavis2)

# %%
df_ex3_mavis2 = load_results("data/exercise3_results_mavis2.json").drop(columns=["Heuristic", "States Generated"])
df_ex3_mavis2
# Out:
#                     Level          Strategy Level solved  Depth  Time/s  Steps
# 0          SAsoko1_08.lvl  NONDETERMINISTIC          Yes      6   0.011      6
# 1      ex3_clearlevel.lvl  NONDETERMINISTIC          Yes      7   1.888      9
# 2  ex3_clutteredlevel.lvl  NONDETERMINISTIC          Yes     11   9.206     14

# %% [markdown]
# ### Exercise 4 (mavis2)

# %%
df_ex4_mavis2 = load_results("data/exercise4_results_mavis2.json").drop(columns=["Heuristic", "States Generated"])
df_ex4_mavis2
# Out:
#                    Level                 Strategy Level solved  Depth  Time/s  \
# 0         SAsoko1_08.lvl  NONDETERMINISTIC_CYCLIC          Yes      6   0.014
# 1  Non_det_Slippery1.lvl  NONDETERMINISTIC_CYCLIC          Yes      2   0.003
# 2  Non_det_Slippery2.lvl  NONDETERMINISTIC_CYCLIC          Yes      4   0.006
# 3   Non_det_slippery.lvl  NONDETERMINISTIC_CYCLIC          Yes      8   0.017
# 4    Non_det_Fumble1.lvl  NONDETERMINISTIC_CYCLIC          Yes      4   0.003
# 5    Non_det_Fumble2.lvl  NONDETERMINISTIC_CYCLIC           No    496   0.000
# 6    Non_det_Clumsy1.lvl  NONDETERMINISTIC_CYCLIC          Yes      4   0.005
# 7    Non_det_Clumsy2.lvl  NONDETERMINISTIC_CYCLIC          Yes      3   0.004
# 8  non_det_slippery3.lvl  NONDETERMINISTIC_CYCLIC          Yes      6   0.035
#
#    Steps
# 0      6
# 1      2
# 2      7
# 3      9
# 4      4
# 5      0
# 6     10
# 7      3
# 8      8

# %% [markdown]
# ## Mavis3 Experiment Results
#
# Loads the mavis3 result JSONs via `analysis.load_results`.

# %% [markdown]
# ### Exercise 2 (mavis3)

# %%
ex2_mavis3_levels = [
"MAhelperCustom.lvl"
]
df_ex2_mavis3 = load_goal_recognition_results("data/exercise2_results_mavis3.json")
df_ex2_mavis3 = (
    df_ex2_mavis3[df_ex2_mavis3["Level"].isin(ex2_mavis3_levels)]
    .set_index("Level")
    .loc[ex2_mavis3_levels]
    .reset_index()
)
df_ex2_mavis3
# Out:
#                 Level Level solved  Initial AND-OR depth  Time/s  Steps
# 0  MAhelperCustom.lvl          Yes                     8   1.067      8
