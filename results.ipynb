# %%
from analysis import load_results
import pandas as pd

# %% [markdown]
# ## Exercise 2

# %%
df_ex2 = load_results("exercise2_results.json")
df_ex2
# Out:
#                Level Strategy Heuristic States Generated   Time/s  \
# 0             MAPF00      BFS         -               48    0.005
# 1             MAPF01      BFS         -             2350    0.338
# 2             MAPF02      BFS         -           110445   48.097
# 3            MAPF02C      BFS         -           110541   48.735
# 4             MAPF03      BFS         -          Timeout  Timeout
# 5            MAPF03C      BFS         -          Timeout  Timeout
# 6  MAPFslidingpuzzle      BFS         -           181255   53.513
# 7       MAPFreorder2      BFS         -          Timeout  Timeout
#
#   Solution length
# 0              14
# 1              14
# 2              14
# 3              14
# 4         Timeout
# 5         Timeout
# 6              28
# 7         Timeout

# %% [markdown]
# ## Exercise 3

# %%
df_ex3 = load_results("exercise3_results.json")
df_ex3

df = pd.concat([df_ex2, df_ex3], ignore_index=True).sort_values('Level')
df[:2].reset_index(drop=True).drop(columns=['Heuristic'])
# Out:
#          Level Strategy States Generated Time/s Solution length
# 0  BFSfriendly      BFS                2  0.003               1
# 1  BFSfriendly      DFS             6575  0.377               1

# %% [markdown]
# ## Excercise 4

# %%
df_ex4 = load_results("exercise4_results.json")
df_ex4[df_ex4['Heuristic'] == "GOALCOUNT"].reset_index(drop=True)
# Out:
#                 Level Strategy  Heuristic States Generated   Time/s  \
# 0              MAPF00    ASTAR  GOALCOUNT               48    0.007
# 1              MAPF00   GREEDY  GOALCOUNT               48    0.007
# 2              MAPF01    ASTAR  GOALCOUNT             2350    0.343
# 3              MAPF01   GREEDY  GOALCOUNT              513    0.015
# 4              MAPF02    ASTAR  GOALCOUNT           110445   49.595
# 5              MAPF02   GREEDY  GOALCOUNT            12810    0.201
# 6             MAPF02C    ASTAR  GOALCOUNT           110489   49.095
# 7             MAPF02C   GREEDY  GOALCOUNT            98700    2.774
# 8              MAPF03    ASTAR  GOALCOUNT          Timeout  Timeout
# 9              MAPF03   GREEDY  GOALCOUNT           148501    2.411
# 10            MAPF03C    ASTAR  GOALCOUNT          Timeout  Timeout
# 11            MAPF03C   GREEDY  GOALCOUNT          Timeout  Timeout
# 12        BFSfriendly    ASTAR  GOALCOUNT                3    0.003
# 13        BFSfriendly   GREEDY  GOALCOUNT             6575    0.384
# 14  MAPFslidingpuzzle    ASTAR  GOALCOUNT           181040   53.919
# 15  MAPFslidingpuzzle   GREEDY  GOALCOUNT            32236    5.675
# 16       MAPFreorder2    ASTAR  GOALCOUNT          Timeout  Timeout
# 17       MAPFreorder2   GREEDY  GOALCOUNT          Timeout  Timeout
#
#    Solution length
# 0               14
# 1               14
# 2               14
# 3               61
# 4               14
# 5              263
# 6               14
# 7                4
# 8          Timeout
# 9              741
# 10         Timeout
# 11         Timeout
# 12               1
# 13               1
# 14              28
# 15              17
# 16         Timeout
# 17         Timeout

# %%
df_ex5 = load_results("exercise5_results.json")

# %%
df_ex5
# Out:
#             Level Strategy     Heuristic States Generated   Time/s  \
# 0            SAD1      BFS             -               80    0.008
# 1            SAD2      BFS             -           646391   37.214
# 2            SAD3      BFS             -          Timeout  Timeout
# 3   SAfriendofBFS      BFS             -              750    0.019
# 4       SAFirefly      BFS             -          1900873   102.08
# 5        SACrunch      BFS             -          Timeout  Timeout
# 6       SAFirefly      DFS             -           279908   14.108
# 7        SACrunch      DFS             -          1289616   59.072
# 8       SAFirefly   GREEDY     GOALCOUNT            12228    0.678
# 9        SACrunch   GREEDY     GOALCOUNT             4146     0.21
# 10     SAsoko1_04   GREEDY      ADVANCED                3    0.002
# 11     SAsoko1_08   GREEDY      ADVANCED               16    0.004
# 12     SAsoko1_16   GREEDY      ADVANCED               61    0.006
# 13     SAsoko1_32   GREEDY      ADVANCED              287    0.018
# 14     SAsoko1_64   GREEDY      ADVANCED             1052     0.06
# 15    SAsoko1_128   GREEDY      ADVANCED             3496    0.185
# 16     SAsoko2_04   GREEDY      ADVANCED               50    0.004
# 17     SAsoko2_08   GREEDY      ADVANCED             2183    0.118
# 18     SAsoko2_16   GREEDY      ADVANCED            16092    0.927
# 19     SAsoko2_32   GREEDY      ADVANCED            55605    3.166
# 20     SAsoko2_64   GREEDY      ADVANCED          Timeout  Timeout
# 21    SAsoko2_128   GREEDY      ADVANCED          Timeout  Timeout
# 22     SAsoko3_04   GREEDY      ADVANCED            17765     0.79
# 23     SAsoko3_05   GREEDY      ADVANCED           657237   25.513
# 24     SAsoko3_06   GREEDY      ADVANCED             None      0.0
# 25     SAsoko3_07   GREEDY      ADVANCED             None      0.0
# 26     SAsoko3_08   GREEDY      ADVANCED             None      0.0
# 27     SAsoko3_16   GREEDY      ADVANCED             None      0.0
# 28     SAsoko3_32   GREEDY      ADVANCED             None      0.0
# 29     SAsoko3_64   GREEDY      ADVANCED             None      0.0
# 30    SAsoko3_128   GREEDY      ADVANCED          Timeout  Timeout
# 31      SAFirefly   GREEDY  ADVANCEDGOAL              207     0.03
# 32       SACrunch   GREEDY  ADVANCEDGOAL              329    0.032
# 33     SAsoko1_04   GREEDY  ADVANCEDGOAL                3    0.008
# 34     SAsoko1_08   GREEDY  ADVANCEDGOAL               11    0.007
# 35     SAsoko1_16   GREEDY  ADVANCEDGOAL               27     0.01
# 36     SAsoko1_32   GREEDY  ADVANCEDGOAL               59    0.009
# 37     SAsoko1_64   GREEDY  ADVANCEDGOAL              123    0.013
# 38    SAsoko1_128   GREEDY  ADVANCEDGOAL              251    0.019
# 39     SAsoko2_04   GREEDY  ADVANCEDGOAL                9    0.003
# 40     SAsoko2_08   GREEDY  ADVANCEDGOAL               29    0.006
# 41     SAsoko2_16   GREEDY  ADVANCEDGOAL               69    0.007
# 42     SAsoko2_32   GREEDY  ADVANCEDGOAL              149     0.01
# 43     SAsoko2_64   GREEDY  ADVANCEDGOAL              309    0.019
# 44    SAsoko2_128   GREEDY  ADVANCEDGOAL              629    0.052
# 45     SAsoko3_04   GREEDY  ADVANCEDGOAL              186    0.021
# 46     SAsoko3_05   GREEDY  ADVANCEDGOAL              316    0.047
# 47     SAsoko3_06   GREEDY  ADVANCEDGOAL              349    0.018
# 48     SAsoko3_07   GREEDY  ADVANCEDGOAL              402    0.031
# 49     SAsoko3_08   GREEDY  ADVANCEDGOAL             1940    0.101
# 50     SAsoko3_16   GREEDY  ADVANCEDGOAL            11707    0.845
# 51     SAsoko3_32   GREEDY  ADVANCEDGOAL            44679    6.134
# 52     SAsoko3_64   GREEDY  ADVANCEDGOAL          Timeout  Timeout
# 53    SAsoko3_128   GREEDY  ADVANCEDGOAL          Timeout  Timeout
#
#    Solution length
# 0               19
# 1               19
# 2          Timeout
# 3                3
# 4               60
# 5          Timeout
# 6              178
# 7              475
# 8                7
# 9              923
# 10               2
# 11               6
# 12              14
# 13              30
# 14              62
# 15             126
# 16               8
# 17             272
# 18             594
# 19               3
# 20         Timeout
# 21         Timeout
# 22               4
# 23             195
# 24               0
# 25               0
# 26               0
# 27               0
# 28               0
# 29               0
# 30         Timeout
# 31              84
# 32             123
# 33               2
# 34               6
# 35              14
# 36              30
# 37              62
# 38             126
# 39               2
# 40               6
# 41              14
# 42              30
# 43              62
# 44             126
# 45              55
# 46              85
# 47              64
# 48              88
# 49             491
# 50               3
# 51              14
# 52         Timeout
# 53         Timeout

# %% [markdown]
# ### Exercise 5.1 — BFS on SAD1, SAD2, SAD3, SAfriendofBFS

# %%
levels_51 = ["SAD1", "SAD2", "SAD3", "SAfriendofBFS"]
df_51 = df_ex5[
    (df_ex5["Level"].isin(levels_51)) & (df_ex5["Strategy"] == "BFS")
][["Level", "Strategy", "Heuristic", "States Generated", "Time/s", "Solution length"]].reset_index(drop=True)
df_51

# %% [markdown]
# ### Exercise 5.2 — BFS and DFS on SAFirefly and SACrunch

# %%
levels_52 = ["SAFirefly", "SACrunch"]
df_52 = df_ex5[
    (df_ex5["Level"].isin(levels_52)) & (df_ex5["Strategy"].isin(["BFS", "DFS"]))
][["Level", "Strategy", "Heuristic", "States Generated", "Time/s", "Solution length"]].reset_index(drop=True)
df_52

# %% [markdown]
# ### Exercise 5.3 — BFS, DFS, and Greedy (GoalCount) on SAFirefly and SACrunch

# %%
levels_53 = ["SAFirefly", "SACrunch"]
mask_53 = (
    (df_ex5["Level"].isin(levels_53)) &
    (
        df_ex5["Strategy"].isin(["BFS", "DFS"]) |
        ((df_ex5["Strategy"] == "GREEDY") & (df_ex5["Heuristic"] == "GOALCOUNT"))
    )
)
df_53 = df_ex5[mask_53][
    ["Level", "Strategy", "Heuristic", "States Generated", "Time/s", "Solution length"]
].reset_index(drop=True)
df_53

# %% [markdown]
# ### Exercise 5.4 — Greedy Best-First with Advanced Heuristics on Sokoban levels

# %%
soko_levels = [
    "SAsoko1_04", "SAsoko1_08", "SAsoko1_16", "SAsoko1_32", "SAsoko1_64", "SAsoko1_128",
    "SAsoko2_04", "SAsoko2_08", "SAsoko2_16", "SAsoko2_32", "SAsoko2_64", "SAsoko2_128",
    "SAsoko3_04", "SAsoko3_05", "SAsoko3_06", "SAsoko3_07", "SAsoko3_08",
    "SAsoko3_16", "SAsoko3_32", "SAsoko3_64", "SAsoko3_128",
]

# Show ADVANCED and ADVANCEDGOAL side-by-side for easy comparison
df_54 = df_ex5[
    (df_ex5["Level"].isin(soko_levels)) &
    (df_ex5["Strategy"] == "GREEDY") &
    (df_ex5["Heuristic"].isin(["ADVANCED", "ADVANCEDGOAL"]))
][["Level", "Heuristic", "States Generated", "Time/s", "Solution length"]].reset_index(drop=True)

df_54_pivot = df_54.pivot_table(
    index="Level",
    columns="Heuristic",
    values=["States Generated", "Time/s", "Solution length"],
    aggfunc="first"
)
# Flatten multi-level columns
df_54_pivot.columns = [f"{col[0]} ({col[1]})" for col in df_54_pivot.columns]
df_54_pivot = df_54_pivot.reindex(soko_levels).reset_index()
df_54_pivot
